# %% [markdown]
# # PyObject:  Object-oriented programming HW 11

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# your solution here

class ChargedParticle(Particle):

    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 # your solution here
# ----> 4 class ChargedParticle(Particle):
#       6     def __init__(self, mass, x, y, z, vx, vy, vz, charge):
#       7         self.mass = mass
#
# NameError: name 'Particle' is not defined

# %%
# write/copy code here

#from last class:

#1
class Particle(object):
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.m = m
        
        p1 = Particle(1,2,3)  #define position values of first particle 
        p2 = Particle(3,2,1)  #define position values of second particle
#2
    def v_mag(vx,vy,vz):
        return np.sqrt((vx**2)+(vy**2)+(vz**2))

    def k_energy(v_mag):
        return ((1/2)*m*(v_mag)**2)

#3

    def find_separation(self, other):
        return np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - other.z)**2)
        distance1 = p1.distance(p2)
        return distance1

#4
    def time_dt(self,dt):
        self.x = (self.x)+((self.vx)*dt)
        self.y = (self.y)+((self.vy)*dt)
        self.z = (self.z)+((self.vz)*dt)
        return self 

#5
import numpy as np
# your solution here

class ChargedParticle(Particle):

    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.

# %%
# write new code here
import numpy as np

class ChargedParticle(Particle):

    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge
        
#6
    def find_separation(self, other):
        return np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - other.z)**2)
    
    def check_separation(self, other): 
        if self.find_separation(other) < 0.25:
            interaction = True
            print("interaction")
            
    def find_separation(self, other):
        return np.sqrt((self.x - other.x)**2 + (self.y - other.y)**2 + (self.z - other.z)**2)
    
    def check_separation(self, other): 
        if self.find_separation(other) < 0.25:
            interaction = True
            print("interaction")   
        else:
            interaction = False
            print("no interaction")
            
        if interaction == True and self.charge == ((other.charge)*(-1)): 
            attraction = True 
        else:
            interaction = False
            self.vx = 0
            self.vy = 0 
            self.vz = 0 
            other.vx = 0
            other.vy = 0 
            other.vz = 0
            self.charge = 0
            other.charge = 0
            
            print("merge")
            
        if interaction == True and self.charge == other.charge:
            
            self.vx = (self.vx)*((-1)*(self.charge+other.charge)*(self.mass/other.mass))
            self.vy = (self.vy)*((-1)*(self.charge+other.charge)*(self.mass/other.mass))
            self.vz = (self.vz)*((-1)*(self.charge+other.charge)*(self.mass/other.mass))
            
            other.vx = (other.vx)*((-1)*(self.charge+other.charge)*(other.mass/self.mass))
            other.vy = (other.vy)*((-1)*(self.charge+other.charge)*(other.mass/self.mass))
            other.vy = (other.vy)*((-1)*(self.charge+other.charge)*(other.mass/self.mass))
            
            print("repel")

    def time_dt(self, dt):
        self.x += self.vx * dt
        self.y += self.vy * dt
        self.z += self.vz * dt
        return self 
    
#7- test mass = 0.5 for both particles

P1 = ChargedParticle(0.5, -5, -5, -5, 1, 1, 1, 0.5)
P2 = ChargedParticle(0.5, 5, 5, 5, -1, -1, -1, -0.5)

import numpy as np
 
for i in np.arange(0, 10, 0.5): 
     
    def time_dt(self,dt):
        self.x = (self.x)+((self.vx)*dt)
        self.y = (self.y)+((self.vy)*dt)
        self.z = (self.z)+((self.vz)*dt)
        return self 
        print(self)        

#8- test mass = 0.5 for both particles

P1 = ChargedParticle(0.5, -5, -5, -5, 2, 2, 2, 0.5)
P2 = ChargedParticle(0.5, 5, 5, 5, -1, -1, -1, 2)

# Move particles in 0.5 time steps for 300 steps

#for i in np.arange(0, 300, 0.5): 
     
#    def time_dt(self,dt):
#        self.x = (self.x)+((self.vx)*dt)
#        self.y = (self.y)+((self.vy)*dt)
#        self.z = (self.z)+((self.vz)*dt)
#        return(self)
#        print(self)
        

dt = 0.5
steps = 300
 
for i in range(steps):
    P1.time_dt(dt)
    P2.time_dt(dt)

    print(f"Step {i+1}:")
    print(f"P1 Position: ({P1.x}, {P1.y}, {P1.z}), Velocity: ({P1.vx}, {P1.vy}, {P1.vz})")
    print(f"P2 Position: ({P2.x}, {P2.y}, {P2.z}), Velocity: ({P2.vx}, {P2.vy}, {P2.vz})")
    print("-" * 40)
# Out:
# Step 1:
# P1 Position: (-4.0, -4.0, -4.0), Velocity: (2, 2, 2)
# P2 Position: (4.5, 4.5, 4.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 2:
# P1 Position: (-3.0, -3.0, -3.0), Velocity: (2, 2, 2)
# P2 Position: (4.0, 4.0, 4.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 3:
# P1 Position: (-2.0, -2.0, -2.0), Velocity: (2, 2, 2)
# P2 Position: (3.5, 3.5, 3.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 4:
# P1 Position: (-1.0, -1.0, -1.0), Velocity: (2, 2, 2)
# P2 Position: (3.0, 3.0, 3.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 5:
# P1 Position: (0.0, 0.0, 0.0), Velocity: (2, 2, 2)
# P2 Position: (2.5, 2.5, 2.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 6:
# P1 Position: (1.0, 1.0, 1.0), Velocity: (2, 2, 2)
# P2 Position: (2.0, 2.0, 2.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 7:
# P1 Position: (2.0, 2.0, 2.0), Velocity: (2, 2, 2)
# P2 Position: (1.5, 1.5, 1.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 8:
# P1 Position: (3.0, 3.0, 3.0), Velocity: (2, 2, 2)
# P2 Position: (1.0, 1.0, 1.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 9:
# P1 Position: (4.0, 4.0, 4.0), Velocity: (2, 2, 2)
# P2 Position: (0.5, 0.5, 0.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 10:
# P1 Position: (5.0, 5.0, 5.0), Velocity: (2, 2, 2)
# P2 Position: (0.0, 0.0, 0.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 11:
# P1 Position: (6.0, 6.0, 6.0), Velocity: (2, 2, 2)
# P2 Position: (-0.5, -0.5, -0.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 12:
# P1 Position: (7.0, 7.0, 7.0), Velocity: (2, 2, 2)
# P2 Position: (-1.0, -1.0, -1.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 13:
# P1 Position: (8.0, 8.0, 8.0), Velocity: (2, 2, 2)
# P2 Position: (-1.5, -1.5, -1.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 14:
# P1 Position: (9.0, 9.0, 9.0), Velocity: (2, 2, 2)
# P2 Position: (-2.0, -2.0, -2.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 15:
# P1 Position: (10.0, 10.0, 10.0), Velocity: (2, 2, 2)
# P2 Position: (-2.5, -2.5, -2.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 16:
# P1 Position: (11.0, 11.0, 11.0), Velocity: (2, 2, 2)
# P2 Position: (-3.0, -3.0, -3.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 17:
# P1 Position: (12.0, 12.0, 12.0), Velocity: (2, 2, 2)
# P2 Position: (-3.5, -3.5, -3.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 18:
# P1 Position: (13.0, 13.0, 13.0), Velocity: (2, 2, 2)
# P2 Position: (-4.0, -4.0, -4.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 19:
# P1 Position: (14.0, 14.0, 14.0), Velocity: (2, 2, 2)
# P2 Position: (-4.5, -4.5, -4.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 20:
# P1 Position: (15.0, 15.0, 15.0), Velocity: (2, 2, 2)
# P2 Position: (-5.0, -5.0, -5.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 21:
# P1 Position: (16.0, 16.0, 16.0), Velocity: (2, 2, 2)
# P2 Position: (-5.5, -5.5, -5.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 22:
# P1 Position: (17.0, 17.0, 17.0), Velocity: (2, 2, 2)
# P2 Position: (-6.0, -6.0, -6.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 23:
# P1 Position: (18.0, 18.0, 18.0), Velocity: (2, 2, 2)
# P2 Position: (-6.5, -6.5, -6.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 24:
# P1 Position: (19.0, 19.0, 19.0), Velocity: (2, 2, 2)
# P2 Position: (-7.0, -7.0, -7.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 25:
# P1 Position: (20.0, 20.0, 20.0), Velocity: (2, 2, 2)
# P2 Position: (-7.5, -7.5, -7.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 26:
# P1 Position: (21.0, 21.0, 21.0), Velocity: (2, 2, 2)
# P2 Position: (-8.0, -8.0, -8.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 27:
# P1 Position: (22.0, 22.0, 22.0), Velocity: (2, 2, 2)
# P2 Position: (-8.5, -8.5, -8.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 28:
# P1 Position: (23.0, 23.0, 23.0), Velocity: (2, 2, 2)
# P2 Position: (-9.0, -9.0, -9.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 29:
# P1 Position: (24.0, 24.0, 24.0), Velocity: (2, 2, 2)
# P2 Position: (-9.5, -9.5, -9.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 30:
# P1 Position: (25.0, 25.0, 25.0), Velocity: (2, 2, 2)
# P2 Position: (-10.0, -10.0, -10.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 31:
# P1 Position: (26.0, 26.0, 26.0), Velocity: (2, 2, 2)
# P2 Position: (-10.5, -10.5, -10.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 32:
# P1 Position: (27.0, 27.0, 27.0), Velocity: (2, 2, 2)
# P2 Position: (-11.0, -11.0, -11.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 33:
# P1 Position: (28.0, 28.0, 28.0), Velocity: (2, 2, 2)
# P2 Position: (-11.5, -11.5, -11.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 34:
# P1 Position: (29.0, 29.0, 29.0), Velocity: (2, 2, 2)
# P2 Position: (-12.0, -12.0, -12.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 35:
# P1 Position: (30.0, 30.0, 30.0), Velocity: (2, 2, 2)
# P2 Position: (-12.5, -12.5, -12.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 36:
# P1 Position: (31.0, 31.0, 31.0), Velocity: (2, 2, 2)
# P2 Position: (-13.0, -13.0, -13.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 37:
# P1 Position: (32.0, 32.0, 32.0), Velocity: (2, 2, 2)
# P2 Position: (-13.5, -13.5, -13.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 38:
# P1 Position: (33.0, 33.0, 33.0), Velocity: (2, 2, 2)
# P2 Position: (-14.0, -14.0, -14.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 39:
# P1 Position: (34.0, 34.0, 34.0), Velocity: (2, 2, 2)
# P2 Position: (-14.5, -14.5, -14.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 40:
# P1 Position: (35.0, 35.0, 35.0), Velocity: (2, 2, 2)
# P2 Position: (-15.0, -15.0, -15.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 41:
# P1 Position: (36.0, 36.0, 36.0), Velocity: (2, 2, 2)
# P2 Position: (-15.5, -15.5, -15.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 42:
# P1 Position: (37.0, 37.0, 37.0), Velocity: (2, 2, 2)
# P2 Position: (-16.0, -16.0, -16.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 43:
# P1 Position: (38.0, 38.0, 38.0), Velocity: (2, 2, 2)
# P2 Position: (-16.5, -16.5, -16.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 44:
# P1 Position: (39.0, 39.0, 39.0), Velocity: (2, 2, 2)
# P2 Position: (-17.0, -17.0, -17.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 45:
# P1 Position: (40.0, 40.0, 40.0), Velocity: (2, 2, 2)
# P2 Position: (-17.5, -17.5, -17.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 46:
# P1 Position: (41.0, 41.0, 41.0), Velocity: (2, 2, 2)
# P2 Position: (-18.0, -18.0, -18.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 47:
# P1 Position: (42.0, 42.0, 42.0), Velocity: (2, 2, 2)
# P2 Position: (-18.5, -18.5, -18.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 48:
# P1 Position: (43.0, 43.0, 43.0), Velocity: (2, 2, 2)
# P2 Position: (-19.0, -19.0, -19.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 49:
# P1 Position: (44.0, 44.0, 44.0), Velocity: (2, 2, 2)
# P2 Position: (-19.5, -19.5, -19.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 50:
# P1 Position: (45.0, 45.0, 45.0), Velocity: (2, 2, 2)
# P2 Position: (-20.0, -20.0, -20.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 51:
# P1 Position: (46.0, 46.0, 46.0), Velocity: (2, 2, 2)
# P2 Position: (-20.5, -20.5, -20.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 52:
# P1 Position: (47.0, 47.0, 47.0), Velocity: (2, 2, 2)
# P2 Position: (-21.0, -21.0, -21.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 53:
# P1 Position: (48.0, 48.0, 48.0), Velocity: (2, 2, 2)
# P2 Position: (-21.5, -21.5, -21.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 54:
# P1 Position: (49.0, 49.0, 49.0), Velocity: (2, 2, 2)
# P2 Position: (-22.0, -22.0, -22.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 55:
# P1 Position: (50.0, 50.0, 50.0), Velocity: (2, 2, 2)
# P2 Position: (-22.5, -22.5, -22.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 56:
# P1 Position: (51.0, 51.0, 51.0), Velocity: (2, 2, 2)
# P2 Position: (-23.0, -23.0, -23.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 57:
# P1 Position: (52.0, 52.0, 52.0), Velocity: (2, 2, 2)
# P2 Position: (-23.5, -23.5, -23.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 58:
# P1 Position: (53.0, 53.0, 53.0), Velocity: (2, 2, 2)
# P2 Position: (-24.0, -24.0, -24.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 59:
# P1 Position: (54.0, 54.0, 54.0), Velocity: (2, 2, 2)
# P2 Position: (-24.5, -24.5, -24.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 60:
# P1 Position: (55.0, 55.0, 55.0), Velocity: (2, 2, 2)
# P2 Position: (-25.0, -25.0, -25.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 61:
# P1 Position: (56.0, 56.0, 56.0), Velocity: (2, 2, 2)
# P2 Position: (-25.5, -25.5, -25.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 62:
# P1 Position: (57.0, 57.0, 57.0), Velocity: (2, 2, 2)
# P2 Position: (-26.0, -26.0, -26.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 63:
# P1 Position: (58.0, 58.0, 58.0), Velocity: (2, 2, 2)
# P2 Position: (-26.5, -26.5, -26.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 64:
# P1 Position: (59.0, 59.0, 59.0), Velocity: (2, 2, 2)
# P2 Position: (-27.0, -27.0, -27.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 65:
# P1 Position: (60.0, 60.0, 60.0), Velocity: (2, 2, 2)
# P2 Position: (-27.5, -27.5, -27.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 66:
# P1 Position: (61.0, 61.0, 61.0), Velocity: (2, 2, 2)
# P2 Position: (-28.0, -28.0, -28.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 67:
# P1 Position: (62.0, 62.0, 62.0), Velocity: (2, 2, 2)
# P2 Position: (-28.5, -28.5, -28.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 68:
# P1 Position: (63.0, 63.0, 63.0), Velocity: (2, 2, 2)
# P2 Position: (-29.0, -29.0, -29.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 69:
# P1 Position: (64.0, 64.0, 64.0), Velocity: (2, 2, 2)
# P2 Position: (-29.5, -29.5, -29.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 70:
# P1 Position: (65.0, 65.0, 65.0), Velocity: (2, 2, 2)
# P2 Position: (-30.0, -30.0, -30.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 71:
# P1 Position: (66.0, 66.0, 66.0), Velocity: (2, 2, 2)
# P2 Position: (-30.5, -30.5, -30.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 72:
# P1 Position: (67.0, 67.0, 67.0), Velocity: (2, 2, 2)
# P2 Position: (-31.0, -31.0, -31.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 73:
# P1 Position: (68.0, 68.0, 68.0), Velocity: (2, 2, 2)
# P2 Position: (-31.5, -31.5, -31.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 74:
# P1 Position: (69.0, 69.0, 69.0), Velocity: (2, 2, 2)
# P2 Position: (-32.0, -32.0, -32.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 75:
# P1 Position: (70.0, 70.0, 70.0), Velocity: (2, 2, 2)
# P2 Position: (-32.5, -32.5, -32.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 76:
# P1 Position: (71.0, 71.0, 71.0), Velocity: (2, 2, 2)
# P2 Position: (-33.0, -33.0, -33.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 77:
# P1 Position: (72.0, 72.0, 72.0), Velocity: (2, 2, 2)
# P2 Position: (-33.5, -33.5, -33.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 78:
# P1 Position: (73.0, 73.0, 73.0), Velocity: (2, 2, 2)
# P2 Position: (-34.0, -34.0, -34.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 79:
# P1 Position: (74.0, 74.0, 74.0), Velocity: (2, 2, 2)
# P2 Position: (-34.5, -34.5, -34.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 80:
# P1 Position: (75.0, 75.0, 75.0), Velocity: (2, 2, 2)
# P2 Position: (-35.0, -35.0, -35.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 81:
# P1 Position: (76.0, 76.0, 76.0), Velocity: (2, 2, 2)
# P2 Position: (-35.5, -35.5, -35.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 82:
# P1 Position: (77.0, 77.0, 77.0), Velocity: (2, 2, 2)
# P2 Position: (-36.0, -36.0, -36.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 83:
# P1 Position: (78.0, 78.0, 78.0), Velocity: (2, 2, 2)
# P2 Position: (-36.5, -36.5, -36.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 84:
# P1 Position: (79.0, 79.0, 79.0), Velocity: (2, 2, 2)
# P2 Position: (-37.0, -37.0, -37.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 85:
# P1 Position: (80.0, 80.0, 80.0), Velocity: (2, 2, 2)
# P2 Position: (-37.5, -37.5, -37.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 86:
# P1 Position: (81.0, 81.0, 81.0), Velocity: (2, 2, 2)
# P2 Position: (-38.0, -38.0, -38.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 87:
# P1 Position: (82.0, 82.0, 82.0), Velocity: (2, 2, 2)
# P2 Position: (-38.5, -38.5, -38.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 88:
# P1 Position: (83.0, 83.0, 83.0), Velocity: (2, 2, 2)
# P2 Position: (-39.0, -39.0, -39.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 89:
# P1 Position: (84.0, 84.0, 84.0), Velocity: (2, 2, 2)
# P2 Position: (-39.5, -39.5, -39.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 90:
# P1 Position: (85.0, 85.0, 85.0), Velocity: (2, 2, 2)
# P2 Position: (-40.0, -40.0, -40.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 91:
# P1 Position: (86.0, 86.0, 86.0), Velocity: (2, 2, 2)
# P2 Position: (-40.5, -40.5, -40.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 92:
# P1 Position: (87.0, 87.0, 87.0), Velocity: (2, 2, 2)
# P2 Position: (-41.0, -41.0, -41.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 93:
# P1 Position: (88.0, 88.0, 88.0), Velocity: (2, 2, 2)
# P2 Position: (-41.5, -41.5, -41.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 94:
# P1 Position: (89.0, 89.0, 89.0), Velocity: (2, 2, 2)
# P2 Position: (-42.0, -42.0, -42.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 95:
# P1 Position: (90.0, 90.0, 90.0), Velocity: (2, 2, 2)
# P2 Position: (-42.5, -42.5, -42.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 96:
# P1 Position: (91.0, 91.0, 91.0), Velocity: (2, 2, 2)
# P2 Position: (-43.0, -43.0, -43.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 97:
# P1 Position: (92.0, 92.0, 92.0), Velocity: (2, 2, 2)
# P2 Position: (-43.5, -43.5, -43.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 98:
# P1 Position: (93.0, 93.0, 93.0), Velocity: (2, 2, 2)
# P2 Position: (-44.0, -44.0, -44.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 99:
# P1 Position: (94.0, 94.0, 94.0), Velocity: (2, 2, 2)
# P2 Position: (-44.5, -44.5, -44.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 100:
# P1 Position: (95.0, 95.0, 95.0), Velocity: (2, 2, 2)
# P2 Position: (-45.0, -45.0, -45.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 101:
# P1 Position: (96.0, 96.0, 96.0), Velocity: (2, 2, 2)
# P2 Position: (-45.5, -45.5, -45.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 102:
# P1 Position: (97.0, 97.0, 97.0), Velocity: (2, 2, 2)
# P2 Position: (-46.0, -46.0, -46.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 103:
# P1 Position: (98.0, 98.0, 98.0), Velocity: (2, 2, 2)
# P2 Position: (-46.5, -46.5, -46.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 104:
# P1 Position: (99.0, 99.0, 99.0), Velocity: (2, 2, 2)
# P2 Position: (-47.0, -47.0, -47.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 105:
# P1 Position: (100.0, 100.0, 100.0), Velocity: (2, 2, 2)
# P2 Position: (-47.5, -47.5, -47.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 106:
# P1 Position: (101.0, 101.0, 101.0), Velocity: (2, 2, 2)
# P2 Position: (-48.0, -48.0, -48.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 107:
# P1 Position: (102.0, 102.0, 102.0), Velocity: (2, 2, 2)
# P2 Position: (-48.5, -48.5, -48.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 108:
# P1 Position: (103.0, 103.0, 103.0), Velocity: (2, 2, 2)
# P2 Position: (-49.0, -49.0, -49.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 109:
# P1 Position: (104.0, 104.0, 104.0), Velocity: (2, 2, 2)
# P2 Position: (-49.5, -49.5, -49.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 110:
# P1 Position: (105.0, 105.0, 105.0), Velocity: (2, 2, 2)
# P2 Position: (-50.0, -50.0, -50.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 111:
# P1 Position: (106.0, 106.0, 106.0), Velocity: (2, 2, 2)
# P2 Position: (-50.5, -50.5, -50.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 112:
# P1 Position: (107.0, 107.0, 107.0), Velocity: (2, 2, 2)
# P2 Position: (-51.0, -51.0, -51.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 113:
# P1 Position: (108.0, 108.0, 108.0), Velocity: (2, 2, 2)
# P2 Position: (-51.5, -51.5, -51.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 114:
# P1 Position: (109.0, 109.0, 109.0), Velocity: (2, 2, 2)
# P2 Position: (-52.0, -52.0, -52.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 115:
# P1 Position: (110.0, 110.0, 110.0), Velocity: (2, 2, 2)
# P2 Position: (-52.5, -52.5, -52.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 116:
# P1 Position: (111.0, 111.0, 111.0), Velocity: (2, 2, 2)
# P2 Position: (-53.0, -53.0, -53.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 117:
# P1 Position: (112.0, 112.0, 112.0), Velocity: (2, 2, 2)
# P2 Position: (-53.5, -53.5, -53.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 118:
# P1 Position: (113.0, 113.0, 113.0), Velocity: (2, 2, 2)
# P2 Position: (-54.0, -54.0, -54.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 119:
# P1 Position: (114.0, 114.0, 114.0), Velocity: (2, 2, 2)
# P2 Position: (-54.5, -54.5, -54.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 120:
# P1 Position: (115.0, 115.0, 115.0), Velocity: (2, 2, 2)
# P2 Position: (-55.0, -55.0, -55.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 121:
# P1 Position: (116.0, 116.0, 116.0), Velocity: (2, 2, 2)
# P2 Position: (-55.5, -55.5, -55.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 122:
# P1 Position: (117.0, 117.0, 117.0), Velocity: (2, 2, 2)
# P2 Position: (-56.0, -56.0, -56.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 123:
# P1 Position: (118.0, 118.0, 118.0), Velocity: (2, 2, 2)
# P2 Position: (-56.5, -56.5, -56.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 124:
# P1 Position: (119.0, 119.0, 119.0), Velocity: (2, 2, 2)
# P2 Position: (-57.0, -57.0, -57.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 125:
# P1 Position: (120.0, 120.0, 120.0), Velocity: (2, 2, 2)
# P2 Position: (-57.5, -57.5, -57.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 126:
# P1 Position: (121.0, 121.0, 121.0), Velocity: (2, 2, 2)
# P2 Position: (-58.0, -58.0, -58.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 127:
# P1 Position: (122.0, 122.0, 122.0), Velocity: (2, 2, 2)
# P2 Position: (-58.5, -58.5, -58.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 128:
# P1 Position: (123.0, 123.0, 123.0), Velocity: (2, 2, 2)
# P2 Position: (-59.0, -59.0, -59.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 129:
# P1 Position: (124.0, 124.0, 124.0), Velocity: (2, 2, 2)
# P2 Position: (-59.5, -59.5, -59.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 130:
# P1 Position: (125.0, 125.0, 125.0), Velocity: (2, 2, 2)
# P2 Position: (-60.0, -60.0, -60.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 131:
# P1 Position: (126.0, 126.0, 126.0), Velocity: (2, 2, 2)
# P2 Position: (-60.5, -60.5, -60.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 132:
# P1 Position: (127.0, 127.0, 127.0), Velocity: (2, 2, 2)
# P2 Position: (-61.0, -61.0, -61.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 133:
# P1 Position: (128.0, 128.0, 128.0), Velocity: (2, 2, 2)
# P2 Position: (-61.5, -61.5, -61.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 134:
# P1 Position: (129.0, 129.0, 129.0), Velocity: (2, 2, 2)
# P2 Position: (-62.0, -62.0, -62.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 135:
# P1 Position: (130.0, 130.0, 130.0), Velocity: (2, 2, 2)
# P2 Position: (-62.5, -62.5, -62.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 136:
# P1 Position: (131.0, 131.0, 131.0), Velocity: (2, 2, 2)
# P2 Position: (-63.0, -63.0, -63.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 137:
# P1 Position: (132.0, 132.0, 132.0), Velocity: (2, 2, 2)
# P2 Position: (-63.5, -63.5, -63.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 138:
# P1 Position: (133.0, 133.0, 133.0), Velocity: (2, 2, 2)
# P2 Position: (-64.0, -64.0, -64.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 139:
# P1 Position: (134.0, 134.0, 134.0), Velocity: (2, 2, 2)
# P2 Position: (-64.5, -64.5, -64.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 140:
# P1 Position: (135.0, 135.0, 135.0), Velocity: (2, 2, 2)
# P2 Position: (-65.0, -65.0, -65.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 141:
# P1 Position: (136.0, 136.0, 136.0), Velocity: (2, 2, 2)
# P2 Position: (-65.5, -65.5, -65.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 142:
# P1 Position: (137.0, 137.0, 137.0), Velocity: (2, 2, 2)
# P2 Position: (-66.0, -66.0, -66.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 143:
# P1 Position: (138.0, 138.0, 138.0), Velocity: (2, 2, 2)
# P2 Position: (-66.5, -66.5, -66.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 144:
# P1 Position: (139.0, 139.0, 139.0), Velocity: (2, 2, 2)
# P2 Position: (-67.0, -67.0, -67.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 145:
# P1 Position: (140.0, 140.0, 140.0), Velocity: (2, 2, 2)
# P2 Position: (-67.5, -67.5, -67.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 146:
# P1 Position: (141.0, 141.0, 141.0), Velocity: (2, 2, 2)
# P2 Position: (-68.0, -68.0, -68.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 147:
# P1 Position: (142.0, 142.0, 142.0), Velocity: (2, 2, 2)
# P2 Position: (-68.5, -68.5, -68.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 148:
# P1 Position: (143.0, 143.0, 143.0), Velocity: (2, 2, 2)
# P2 Position: (-69.0, -69.0, -69.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 149:
# P1 Position: (144.0, 144.0, 144.0), Velocity: (2, 2, 2)
# P2 Position: (-69.5, -69.5, -69.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 150:
# P1 Position: (145.0, 145.0, 145.0), Velocity: (2, 2, 2)
# P2 Position: (-70.0, -70.0, -70.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 151:
# P1 Position: (146.0, 146.0, 146.0), Velocity: (2, 2, 2)
# P2 Position: (-70.5, -70.5, -70.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 152:
# P1 Position: (147.0, 147.0, 147.0), Velocity: (2, 2, 2)
# P2 Position: (-71.0, -71.0, -71.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 153:
# P1 Position: (148.0, 148.0, 148.0), Velocity: (2, 2, 2)
# P2 Position: (-71.5, -71.5, -71.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 154:
# P1 Position: (149.0, 149.0, 149.0), Velocity: (2, 2, 2)
# P2 Position: (-72.0, -72.0, -72.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 155:
# P1 Position: (150.0, 150.0, 150.0), Velocity: (2, 2, 2)
# P2 Position: (-72.5, -72.5, -72.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 156:
# P1 Position: (151.0, 151.0, 151.0), Velocity: (2, 2, 2)
# P2 Position: (-73.0, -73.0, -73.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 157:
# P1 Position: (152.0, 152.0, 152.0), Velocity: (2, 2, 2)
# P2 Position: (-73.5, -73.5, -73.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 158:
# P1 Position: (153.0, 153.0, 153.0), Velocity: (2, 2, 2)
# P2 Position: (-74.0, -74.0, -74.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 159:
# P1 Position: (154.0, 154.0, 154.0), Velocity: (2, 2, 2)
# P2 Position: (-74.5, -74.5, -74.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 160:
# P1 Position: (155.0, 155.0, 155.0), Velocity: (2, 2, 2)
# P2 Position: (-75.0, -75.0, -75.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 161:
# P1 Position: (156.0, 156.0, 156.0), Velocity: (2, 2, 2)
# P2 Position: (-75.5, -75.5, -75.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 162:
# P1 Position: (157.0, 157.0, 157.0), Velocity: (2, 2, 2)
# P2 Position: (-76.0, -76.0, -76.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 163:
# P1 Position: (158.0, 158.0, 158.0), Velocity: (2, 2, 2)
# P2 Position: (-76.5, -76.5, -76.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 164:
# P1 Position: (159.0, 159.0, 159.0), Velocity: (2, 2, 2)
# P2 Position: (-77.0, -77.0, -77.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 165:
# P1 Position: (160.0, 160.0, 160.0), Velocity: (2, 2, 2)
# P2 Position: (-77.5, -77.5, -77.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 166:
# P1 Position: (161.0, 161.0, 161.0), Velocity: (2, 2, 2)
# P2 Position: (-78.0, -78.0, -78.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 167:
# P1 Position: (162.0, 162.0, 162.0), Velocity: (2, 2, 2)
# P2 Position: (-78.5, -78.5, -78.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 168:
# P1 Position: (163.0, 163.0, 163.0), Velocity: (2, 2, 2)
# P2 Position: (-79.0, -79.0, -79.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 169:
# P1 Position: (164.0, 164.0, 164.0), Velocity: (2, 2, 2)
# P2 Position: (-79.5, -79.5, -79.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 170:
# P1 Position: (165.0, 165.0, 165.0), Velocity: (2, 2, 2)
# P2 Position: (-80.0, -80.0, -80.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 171:
# P1 Position: (166.0, 166.0, 166.0), Velocity: (2, 2, 2)
# P2 Position: (-80.5, -80.5, -80.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 172:
# P1 Position: (167.0, 167.0, 167.0), Velocity: (2, 2, 2)
# P2 Position: (-81.0, -81.0, -81.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 173:
# P1 Position: (168.0, 168.0, 168.0), Velocity: (2, 2, 2)
# P2 Position: (-81.5, -81.5, -81.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 174:
# P1 Position: (169.0, 169.0, 169.0), Velocity: (2, 2, 2)
# P2 Position: (-82.0, -82.0, -82.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 175:
# P1 Position: (170.0, 170.0, 170.0), Velocity: (2, 2, 2)
# P2 Position: (-82.5, -82.5, -82.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 176:
# P1 Position: (171.0, 171.0, 171.0), Velocity: (2, 2, 2)
# P2 Position: (-83.0, -83.0, -83.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 177:
# P1 Position: (172.0, 172.0, 172.0), Velocity: (2, 2, 2)
# P2 Position: (-83.5, -83.5, -83.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 178:
# P1 Position: (173.0, 173.0, 173.0), Velocity: (2, 2, 2)
# P2 Position: (-84.0, -84.0, -84.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 179:
# P1 Position: (174.0, 174.0, 174.0), Velocity: (2, 2, 2)
# P2 Position: (-84.5, -84.5, -84.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 180:
# P1 Position: (175.0, 175.0, 175.0), Velocity: (2, 2, 2)
# P2 Position: (-85.0, -85.0, -85.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 181:
# P1 Position: (176.0, 176.0, 176.0), Velocity: (2, 2, 2)
# P2 Position: (-85.5, -85.5, -85.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 182:
# P1 Position: (177.0, 177.0, 177.0), Velocity: (2, 2, 2)
# P2 Position: (-86.0, -86.0, -86.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 183:
# P1 Position: (178.0, 178.0, 178.0), Velocity: (2, 2, 2)
# P2 Position: (-86.5, -86.5, -86.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 184:
# P1 Position: (179.0, 179.0, 179.0), Velocity: (2, 2, 2)
# P2 Position: (-87.0, -87.0, -87.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 185:
# P1 Position: (180.0, 180.0, 180.0), Velocity: (2, 2, 2)
# P2 Position: (-87.5, -87.5, -87.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 186:
# P1 Position: (181.0, 181.0, 181.0), Velocity: (2, 2, 2)
# P2 Position: (-88.0, -88.0, -88.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 187:
# P1 Position: (182.0, 182.0, 182.0), Velocity: (2, 2, 2)
# P2 Position: (-88.5, -88.5, -88.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 188:
# P1 Position: (183.0, 183.0, 183.0), Velocity: (2, 2, 2)
# P2 Position: (-89.0, -89.0, -89.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 189:
# P1 Position: (184.0, 184.0, 184.0), Velocity: (2, 2, 2)
# P2 Position: (-89.5, -89.5, -89.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 190:
# P1 Position: (185.0, 185.0, 185.0), Velocity: (2, 2, 2)
# P2 Position: (-90.0, -90.0, -90.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 191:
# P1 Position: (186.0, 186.0, 186.0), Velocity: (2, 2, 2)
# P2 Position: (-90.5, -90.5, -90.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 192:
# P1 Position: (187.0, 187.0, 187.0), Velocity: (2, 2, 2)
# P2 Position: (-91.0, -91.0, -91.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 193:
# P1 Position: (188.0, 188.0, 188.0), Velocity: (2, 2, 2)
# P2 Position: (-91.5, -91.5, -91.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 194:
# P1 Position: (189.0, 189.0, 189.0), Velocity: (2, 2, 2)
# P2 Position: (-92.0, -92.0, -92.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 195:
# P1 Position: (190.0, 190.0, 190.0), Velocity: (2, 2, 2)
# P2 Position: (-92.5, -92.5, -92.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 196:
# P1 Position: (191.0, 191.0, 191.0), Velocity: (2, 2, 2)
# P2 Position: (-93.0, -93.0, -93.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 197:
# P1 Position: (192.0, 192.0, 192.0), Velocity: (2, 2, 2)
# P2 Position: (-93.5, -93.5, -93.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 198:
# P1 Position: (193.0, 193.0, 193.0), Velocity: (2, 2, 2)
# P2 Position: (-94.0, -94.0, -94.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 199:
# P1 Position: (194.0, 194.0, 194.0), Velocity: (2, 2, 2)
# P2 Position: (-94.5, -94.5, -94.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 200:
# P1 Position: (195.0, 195.0, 195.0), Velocity: (2, 2, 2)
# P2 Position: (-95.0, -95.0, -95.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 201:
# P1 Position: (196.0, 196.0, 196.0), Velocity: (2, 2, 2)
# P2 Position: (-95.5, -95.5, -95.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 202:
# P1 Position: (197.0, 197.0, 197.0), Velocity: (2, 2, 2)
# P2 Position: (-96.0, -96.0, -96.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 203:
# P1 Position: (198.0, 198.0, 198.0), Velocity: (2, 2, 2)
# P2 Position: (-96.5, -96.5, -96.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 204:
# P1 Position: (199.0, 199.0, 199.0), Velocity: (2, 2, 2)
# P2 Position: (-97.0, -97.0, -97.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 205:
# P1 Position: (200.0, 200.0, 200.0), Velocity: (2, 2, 2)
# P2 Position: (-97.5, -97.5, -97.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 206:
# P1 Position: (201.0, 201.0, 201.0), Velocity: (2, 2, 2)
# P2 Position: (-98.0, -98.0, -98.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 207:
# P1 Position: (202.0, 202.0, 202.0), Velocity: (2, 2, 2)
# P2 Position: (-98.5, -98.5, -98.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 208:
# P1 Position: (203.0, 203.0, 203.0), Velocity: (2, 2, 2)
# P2 Position: (-99.0, -99.0, -99.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 209:
# P1 Position: (204.0, 204.0, 204.0), Velocity: (2, 2, 2)
# P2 Position: (-99.5, -99.5, -99.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 210:
# P1 Position: (205.0, 205.0, 205.0), Velocity: (2, 2, 2)
# P2 Position: (-100.0, -100.0, -100.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 211:
# P1 Position: (206.0, 206.0, 206.0), Velocity: (2, 2, 2)
# P2 Position: (-100.5, -100.5, -100.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 212:
# P1 Position: (207.0, 207.0, 207.0), Velocity: (2, 2, 2)
# P2 Position: (-101.0, -101.0, -101.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 213:
# P1 Position: (208.0, 208.0, 208.0), Velocity: (2, 2, 2)
# P2 Position: (-101.5, -101.5, -101.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 214:
# P1 Position: (209.0, 209.0, 209.0), Velocity: (2, 2, 2)
# P2 Position: (-102.0, -102.0, -102.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 215:
# P1 Position: (210.0, 210.0, 210.0), Velocity: (2, 2, 2)
# P2 Position: (-102.5, -102.5, -102.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 216:
# P1 Position: (211.0, 211.0, 211.0), Velocity: (2, 2, 2)
# P2 Position: (-103.0, -103.0, -103.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 217:
# P1 Position: (212.0, 212.0, 212.0), Velocity: (2, 2, 2)
# P2 Position: (-103.5, -103.5, -103.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 218:
# P1 Position: (213.0, 213.0, 213.0), Velocity: (2, 2, 2)
# P2 Position: (-104.0, -104.0, -104.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 219:
# P1 Position: (214.0, 214.0, 214.0), Velocity: (2, 2, 2)
# P2 Position: (-104.5, -104.5, -104.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 220:
# P1 Position: (215.0, 215.0, 215.0), Velocity: (2, 2, 2)
# P2 Position: (-105.0, -105.0, -105.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 221:
# P1 Position: (216.0, 216.0, 216.0), Velocity: (2, 2, 2)
# P2 Position: (-105.5, -105.5, -105.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 222:
# P1 Position: (217.0, 217.0, 217.0), Velocity: (2, 2, 2)
# P2 Position: (-106.0, -106.0, -106.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 223:
# P1 Position: (218.0, 218.0, 218.0), Velocity: (2, 2, 2)
# P2 Position: (-106.5, -106.5, -106.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 224:
# P1 Position: (219.0, 219.0, 219.0), Velocity: (2, 2, 2)
# P2 Position: (-107.0, -107.0, -107.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 225:
# P1 Position: (220.0, 220.0, 220.0), Velocity: (2, 2, 2)
# P2 Position: (-107.5, -107.5, -107.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 226:
# P1 Position: (221.0, 221.0, 221.0), Velocity: (2, 2, 2)
# P2 Position: (-108.0, -108.0, -108.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 227:
# P1 Position: (222.0, 222.0, 222.0), Velocity: (2, 2, 2)
# P2 Position: (-108.5, -108.5, -108.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 228:
# P1 Position: (223.0, 223.0, 223.0), Velocity: (2, 2, 2)
# P2 Position: (-109.0, -109.0, -109.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 229:
# P1 Position: (224.0, 224.0, 224.0), Velocity: (2, 2, 2)
# P2 Position: (-109.5, -109.5, -109.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 230:
# P1 Position: (225.0, 225.0, 225.0), Velocity: (2, 2, 2)
# P2 Position: (-110.0, -110.0, -110.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 231:
# P1 Position: (226.0, 226.0, 226.0), Velocity: (2, 2, 2)
# P2 Position: (-110.5, -110.5, -110.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 232:
# P1 Position: (227.0, 227.0, 227.0), Velocity: (2, 2, 2)
# P2 Position: (-111.0, -111.0, -111.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 233:
# P1 Position: (228.0, 228.0, 228.0), Velocity: (2, 2, 2)
# P2 Position: (-111.5, -111.5, -111.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 234:
# P1 Position: (229.0, 229.0, 229.0), Velocity: (2, 2, 2)
# P2 Position: (-112.0, -112.0, -112.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 235:
# P1 Position: (230.0, 230.0, 230.0), Velocity: (2, 2, 2)
# P2 Position: (-112.5, -112.5, -112.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 236:
# P1 Position: (231.0, 231.0, 231.0), Velocity: (2, 2, 2)
# P2 Position: (-113.0, -113.0, -113.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 237:
# P1 Position: (232.0, 232.0, 232.0), Velocity: (2, 2, 2)
# P2 Position: (-113.5, -113.5, -113.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 238:
# P1 Position: (233.0, 233.0, 233.0), Velocity: (2, 2, 2)
# P2 Position: (-114.0, -114.0, -114.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 239:
# P1 Position: (234.0, 234.0, 234.0), Velocity: (2, 2, 2)
# P2 Position: (-114.5, -114.5, -114.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 240:
# P1 Position: (235.0, 235.0, 235.0), Velocity: (2, 2, 2)
# P2 Position: (-115.0, -115.0, -115.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 241:
# P1 Position: (236.0, 236.0, 236.0), Velocity: (2, 2, 2)
# P2 Position: (-115.5, -115.5, -115.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 242:
# P1 Position: (237.0, 237.0, 237.0), Velocity: (2, 2, 2)
# P2 Position: (-116.0, -116.0, -116.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 243:
# P1 Position: (238.0, 238.0, 238.0), Velocity: (2, 2, 2)
# P2 Position: (-116.5, -116.5, -116.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 244:
# P1 Position: (239.0, 239.0, 239.0), Velocity: (2, 2, 2)
# P2 Position: (-117.0, -117.0, -117.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 245:
# P1 Position: (240.0, 240.0, 240.0), Velocity: (2, 2, 2)
# P2 Position: (-117.5, -117.5, -117.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 246:
# P1 Position: (241.0, 241.0, 241.0), Velocity: (2, 2, 2)
# P2 Position: (-118.0, -118.0, -118.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 247:
# P1 Position: (242.0, 242.0, 242.0), Velocity: (2, 2, 2)
# P2 Position: (-118.5, -118.5, -118.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 248:
# P1 Position: (243.0, 243.0, 243.0), Velocity: (2, 2, 2)
# P2 Position: (-119.0, -119.0, -119.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 249:
# P1 Position: (244.0, 244.0, 244.0), Velocity: (2, 2, 2)
# P2 Position: (-119.5, -119.5, -119.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 250:
# P1 Position: (245.0, 245.0, 245.0), Velocity: (2, 2, 2)
# P2 Position: (-120.0, -120.0, -120.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 251:
# P1 Position: (246.0, 246.0, 246.0), Velocity: (2, 2, 2)
# P2 Position: (-120.5, -120.5, -120.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 252:
# P1 Position: (247.0, 247.0, 247.0), Velocity: (2, 2, 2)
# P2 Position: (-121.0, -121.0, -121.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 253:
# P1 Position: (248.0, 248.0, 248.0), Velocity: (2, 2, 2)
# P2 Position: (-121.5, -121.5, -121.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 254:
# P1 Position: (249.0, 249.0, 249.0), Velocity: (2, 2, 2)
# P2 Position: (-122.0, -122.0, -122.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 255:
# P1 Position: (250.0, 250.0, 250.0), Velocity: (2, 2, 2)
# P2 Position: (-122.5, -122.5, -122.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 256:
# P1 Position: (251.0, 251.0, 251.0), Velocity: (2, 2, 2)
# P2 Position: (-123.0, -123.0, -123.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 257:
# P1 Position: (252.0, 252.0, 252.0), Velocity: (2, 2, 2)
# P2 Position: (-123.5, -123.5, -123.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 258:
# P1 Position: (253.0, 253.0, 253.0), Velocity: (2, 2, 2)
# P2 Position: (-124.0, -124.0, -124.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 259:
# P1 Position: (254.0, 254.0, 254.0), Velocity: (2, 2, 2)
# P2 Position: (-124.5, -124.5, -124.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 260:
# P1 Position: (255.0, 255.0, 255.0), Velocity: (2, 2, 2)
# P2 Position: (-125.0, -125.0, -125.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 261:
# P1 Position: (256.0, 256.0, 256.0), Velocity: (2, 2, 2)
# P2 Position: (-125.5, -125.5, -125.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 262:
# P1 Position: (257.0, 257.0, 257.0), Velocity: (2, 2, 2)
# P2 Position: (-126.0, -126.0, -126.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 263:
# P1 Position: (258.0, 258.0, 258.0), Velocity: (2, 2, 2)
# P2 Position: (-126.5, -126.5, -126.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 264:
# P1 Position: (259.0, 259.0, 259.0), Velocity: (2, 2, 2)
# P2 Position: (-127.0, -127.0, -127.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 265:
# P1 Position: (260.0, 260.0, 260.0), Velocity: (2, 2, 2)
# P2 Position: (-127.5, -127.5, -127.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 266:
# P1 Position: (261.0, 261.0, 261.0), Velocity: (2, 2, 2)
# P2 Position: (-128.0, -128.0, -128.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 267:
# P1 Position: (262.0, 262.0, 262.0), Velocity: (2, 2, 2)
# P2 Position: (-128.5, -128.5, -128.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 268:
# P1 Position: (263.0, 263.0, 263.0), Velocity: (2, 2, 2)
# P2 Position: (-129.0, -129.0, -129.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 269:
# P1 Position: (264.0, 264.0, 264.0), Velocity: (2, 2, 2)
# P2 Position: (-129.5, -129.5, -129.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 270:
# P1 Position: (265.0, 265.0, 265.0), Velocity: (2, 2, 2)
# P2 Position: (-130.0, -130.0, -130.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 271:
# P1 Position: (266.0, 266.0, 266.0), Velocity: (2, 2, 2)
# P2 Position: (-130.5, -130.5, -130.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 272:
# P1 Position: (267.0, 267.0, 267.0), Velocity: (2, 2, 2)
# P2 Position: (-131.0, -131.0, -131.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 273:
# P1 Position: (268.0, 268.0, 268.0), Velocity: (2, 2, 2)
# P2 Position: (-131.5, -131.5, -131.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 274:
# P1 Position: (269.0, 269.0, 269.0), Velocity: (2, 2, 2)
# P2 Position: (-132.0, -132.0, -132.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 275:
# P1 Position: (270.0, 270.0, 270.0), Velocity: (2, 2, 2)
# P2 Position: (-132.5, -132.5, -132.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 276:
# P1 Position: (271.0, 271.0, 271.0), Velocity: (2, 2, 2)
# P2 Position: (-133.0, -133.0, -133.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 277:
# P1 Position: (272.0, 272.0, 272.0), Velocity: (2, 2, 2)
# P2 Position: (-133.5, -133.5, -133.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 278:
# P1 Position: (273.0, 273.0, 273.0), Velocity: (2, 2, 2)
# P2 Position: (-134.0, -134.0, -134.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 279:
# P1 Position: (274.0, 274.0, 274.0), Velocity: (2, 2, 2)
# P2 Position: (-134.5, -134.5, -134.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 280:
# P1 Position: (275.0, 275.0, 275.0), Velocity: (2, 2, 2)
# P2 Position: (-135.0, -135.0, -135.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 281:
# P1 Position: (276.0, 276.0, 276.0), Velocity: (2, 2, 2)
# P2 Position: (-135.5, -135.5, -135.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 282:
# P1 Position: (277.0, 277.0, 277.0), Velocity: (2, 2, 2)
# P2 Position: (-136.0, -136.0, -136.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 283:
# P1 Position: (278.0, 278.0, 278.0), Velocity: (2, 2, 2)
# P2 Position: (-136.5, -136.5, -136.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 284:
# P1 Position: (279.0, 279.0, 279.0), Velocity: (2, 2, 2)
# P2 Position: (-137.0, -137.0, -137.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 285:
# P1 Position: (280.0, 280.0, 280.0), Velocity: (2, 2, 2)
# P2 Position: (-137.5, -137.5, -137.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 286:
# P1 Position: (281.0, 281.0, 281.0), Velocity: (2, 2, 2)
# P2 Position: (-138.0, -138.0, -138.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 287:
# P1 Position: (282.0, 282.0, 282.0), Velocity: (2, 2, 2)
# P2 Position: (-138.5, -138.5, -138.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 288:
# P1 Position: (283.0, 283.0, 283.0), Velocity: (2, 2, 2)
# P2 Position: (-139.0, -139.0, -139.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 289:
# P1 Position: (284.0, 284.0, 284.0), Velocity: (2, 2, 2)
# P2 Position: (-139.5, -139.5, -139.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 290:
# P1 Position: (285.0, 285.0, 285.0), Velocity: (2, 2, 2)
# P2 Position: (-140.0, -140.0, -140.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 291:
# P1 Position: (286.0, 286.0, 286.0), Velocity: (2, 2, 2)
# P2 Position: (-140.5, -140.5, -140.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 292:
# P1 Position: (287.0, 287.0, 287.0), Velocity: (2, 2, 2)
# P2 Position: (-141.0, -141.0, -141.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 293:
# P1 Position: (288.0, 288.0, 288.0), Velocity: (2, 2, 2)
# P2 Position: (-141.5, -141.5, -141.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 294:
# P1 Position: (289.0, 289.0, 289.0), Velocity: (2, 2, 2)
# P2 Position: (-142.0, -142.0, -142.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 295:
# P1 Position: (290.0, 290.0, 290.0), Velocity: (2, 2, 2)
# P2 Position: (-142.5, -142.5, -142.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 296:
# P1 Position: (291.0, 291.0, 291.0), Velocity: (2, 2, 2)
# P2 Position: (-143.0, -143.0, -143.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 297:
# P1 Position: (292.0, 292.0, 292.0), Velocity: (2, 2, 2)
# P2 Position: (-143.5, -143.5, -143.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 298:
# P1 Position: (293.0, 293.0, 293.0), Velocity: (2, 2, 2)
# P2 Position: (-144.0, -144.0, -144.0), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 299:
# P1 Position: (294.0, 294.0, 294.0), Velocity: (2, 2, 2)
# P2 Position: (-144.5, -144.5, -144.5), Velocity: (-1, -1, -1)
# ----------------------------------------
# Step 300:
# P1 Position: (295.0, 295.0, 295.0), Velocity: (2, 2, 2)
# P2 Position: (-145.0, -145.0, -145.0), Velocity: (-1, -1, -1)
# ----------------------------------------
